# %% [markdown]
# <a href="https://colab.research.google.com/github/dflynnwit/dflynn.github.io/blob/master/IntroductionToPythonForMathTransforms2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Python in Colab Notebooks
# Python is an interpreted language (i.e. not compiled like C or C++ etc.) One advantage, is that you can quickly get the results of the calculation. A downside is that the calculation is slower in most cases than C or C++. However, there are libraries that you can load in that perform calculations on par with C/C++ for some types of applications.
#
# The notebook you have open is hosted online by Google. It consists of cells (the text here is in a *text* cell), whereas your calculations and small programs are written and exectured in a *Code* cell).
# If you double click on this cell, you will see the source text used the generated the nicer looking Rich text that you see here.
#
# Note that we can also write mathematical expressions (You don't need to do nice but it's nice to know):
# $$x=\frac{-b \pm \sqrt{b^2-4ac}}{2a}$$

# %% [markdown]
# # This is an example of a text cell. You can double-click and start editing here
# Regular sized text
# ## A subtitle
# ### A section
# #### A subsection
# **Bold text**
#
# Italic text
#
# *italicised text*
#
# `Computer code and calculations in text`
#
# Images can be inserted too, either as http (url) links, or using 7bit image file
#
# ![PaperBagPlasticBag_set_in_set.png](data:image/png;base64,...)

# %%
# This is an example of a code cell.
# The Hash symbol i.e. # is used for comments, i.e. written stuff for humans that the machines must ignore
# The next space below can be filled in with either more comments, or calculations, code etc...

# %% [markdown]
# ## Ex1 a simple calculation
# We can perform simple calculator type of calculations:

# %%
1+1

# %%
3/2

# %%
sin(90)

# %% [markdown]
# This didn't work!
#
# Not everything is built into a computer lanaguage. Or sometimes, to save space, parts that are not likely to be used are available in libraries or modules. We have to import these
#
# Here we are missing the maths library

# %% [markdown]
# Some calculations need a special maths library. If we use
# ```
# from math import *
# ```
#
# we literally get all the functions. There are other ways to do this though. Look at this another time.

# %%
from math import *
sin(90)
# Out:
# 0.8939966636005579

# %%
# note it will expect radians, so you can convert it by hand or use another function

# %%
cos(0) # remember that 0 radians and 0 deg is just 0
# Out:
# 1.0

# %%
# ?degrees

# %%
# ?radians

# %%
sin(radians(90))
# Out:
# 1.0

# %%
cos(radians(90))

# %% [markdown]
# The answer above should be zero but at 10**-17 on a computer is effectivly zero.

# %%
degrees(acos(0))

# %% [markdown]
# variables

# %%
a=2
b=3

# %%
a+b

# %%
a**b

# %%
b**a

# %% [markdown]
# ### Working with lots of numbers
# We can create a list of number using the square brackets

# %%
xvals = [0,1,2,3,4,5,6,7,8]
yvals = [0,2,4,6,8,10,12,14,16]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(xvals,yvals)
